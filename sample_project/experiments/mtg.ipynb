# %%
import pandas as pd
import numpy as np

# %%
cards = pd.read_csv('../MTG_CSVs/cards.csv')
cards.head()
# Out:
# /tmp/ipykernel_13062/142374483.py:1: DtypeWarning: Columns (3,11,17,21,25,28,52,57,58,65,66,75,76,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   cards = pd.read_csv('../MTG_CSVs/cards.csv')
#    index  id        artist asciiName  attractionLights availability  \
# 0      0   1  Pete Venters       NaN               NaN   mtgo,paper
# 1      1   2  Pete Venters       NaN               NaN   mtgo,paper
# 2      2   3   Volkan Baǵa       NaN               NaN   mtgo,paper
# 3      3   4   Volkan Baǵa       NaN               NaN   mtgo,paper
# 4      4   5      Mark Zug       NaN               NaN   mtgo,paper
#
#   boosterTypes borderColor  cardKingdomEtchedId  cardKingdomFoilId  ...  \
# 0        draft       black                  NaN                NaN  ...
# 1        draft       black                  NaN           123087.0  ...
# 2        draft       black                  NaN                NaN  ...
# ...

# %%
cards.columns
# Out:
# Index(['index', 'id', 'artist', 'asciiName', 'attractionLights',
#        'availability', 'boosterTypes', 'borderColor', 'cardKingdomEtchedId',
#        'cardKingdomFoilId', 'cardKingdomId', 'cardParts', 'cardsphereId',
#        'colorIdentity', 'colorIndicator', 'colors', 'convertedManaCost',
#        'duelDeck', 'edhrecRank', 'edhrecSaltiness', 'faceConvertedManaCost',
#        'faceFlavorName', 'faceManaValue', 'faceName', 'finishes', 'flavorName',
#        'flavorText', 'frameEffects', 'frameVersion', 'hand',
#        'hasAlternativeDeckLimit', 'hasContentWarning', 'hasFoil', 'hasNonFoil',
#        'isAlternative', 'isFullArt', 'isFunny', 'isOnlineOnly', 'isOversized',
#        'isPromo', 'isRebalanced', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'keywords',
#        'language', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'manaValue', 'mcmId', 'mtgArenaId', 'mtgjsonFoilVersionId',
# ...

# %%
cards_cleaned = cards[[
    'id',
    'colorIdentity',
    'colorIndicator',
    'colors',
    'convertedManaCost',
    'edhrecRank',
    'leadershipSkills',
    'life',
    'loyalty',
    'manaCost',
    'manaValue',
    'name',
    'number',
    'power',
    'subsets',
    'subtypes',
    'supertypes',
    'text',
    'toughness',
    'type',
    'types'
]]
cards_cleaned.head()
# Out:
#    id colorIdentity colorIndicator colors  convertedManaCost  edhrecRank  \
# 0   1             W            NaN      W                7.0     18952.0
# 1   2             W            NaN      W                7.0     18952.0
# 2   3             W            NaN      W                5.0     15322.0
# 3   4             W            NaN      W                5.0     15322.0
# 4   5             W            NaN      W                3.0     20452.0
#
#   leadershipSkills  life loyalty   manaCost  ...               name number  \
# 0              NaN   NaN     NaN  {5}{W}{W}  ...  Ancestor's Chosen      1
# 1              NaN   NaN     NaN  {5}{W}{W}  ...  Ancestor's Chosen     1★
# 2              NaN   NaN     NaN     {4}{W}  ...     Angel of Mercy      2
# 3              NaN   NaN     NaN     {4}{W}  ...     Angel of Mercy     2★
# 4              NaN   NaN     NaN     {2}{W}  ...   Angelic Blessing      3
#
#   power subsets      subtypes supertypes  \
# ...

# %%
cards[cards['hasAlternativeDeckLimit'] != 0]['hasAlternativeDeckLimit'].head()
# Out:
# 236      1
# 898      1
# 4104     1
# 7257     1
# 24493    1
# Name: hasAlternativeDeckLimit, dtype: int64
