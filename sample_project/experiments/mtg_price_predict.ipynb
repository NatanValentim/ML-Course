# %%
import pandas as pd

# %%
mtg_prices = pd.read_json('../MTG_CSVs/AllPrices.json')
mtg_prices.head()
# Out:
#                                                 meta  \
# date                                      2023-03-10
# version                               5.2.1+20230310
# 00010d56-fe38-5e35-8aed-518019aa36a5             NaN
# 0001e0d0-2dcd-5640-aadc-a84765cf5fc9             NaN
# 0003caab-9ff5-5d1a-bc06-976dd0457f19             NaN
#
#                                                                                    data
# date                                                                                NaN
# version                                                                             NaN
# 00010d56-fe38-5e35-8aed-518019aa36a5  {'paper': {'cardkingdom': {'buylist': {'foil':...
# 0001e0d0-2dcd-5640-aadc-a84765cf5fc9  {'paper': {'cardkingdom': {'buylist': {'normal...
# 0003caab-9ff5-5d1a-bc06-976dd0457f19  {'mtgo': {'cardhoarder': {'retail': {'foil': {...

# %%
mtg_prices.dtypes
# Out:
# meta    object
# data    object
# dtype: object

# %%
card = mtg_prices['data'][2]

# %%
card
# Out:
# {'paper': {'cardkingdom': {'buylist': {'foil': {'2022-12-10': 1.5,
#      '2022-12-11': 1.5,
#      '2022-12-12': 1.5,
#      '2022-12-13': 1.5,
#      '2022-12-14': 1.5,
#      '2022-12-15': 1.5,
#      '2022-12-16': 1.5,
#      '2022-12-18': 1.5,
#      '2022-12-19': 1.5,
#      '2022-12-20': 1.5,
#      '2022-12-21': 1.5,
#      '2022-12-23': 1.5,
#      '2022-12-24': 1.5,
#      '2022-12-25': 1.5,
#      '2022-12-26': 1.5,
#      '2022-12-27': 1.5,
#      '2022-12-28': 1.5,
#      '2022-12-29': 1.5,
#      '2022-12-30': 1.5,
#      '2022-12-31': 1.5,
#      '2023-01-01': 1.5,
#      '2023-01-02': 1.5,
#      '2023-01-03': 3.0,
#      '2023-01-04': 4.0,
#      '2023-01-05': 4.8,
#      '2023-01-06': 4.8,
#      '2023-01-07': 4.8,
#      '2023-01-08': 4.8,
#      '2023-01-09': 4.8,
#      '2023-01-10': 4.8,
#      '2023-01-11': 4.8,
#      '2023-01-12': 4.8,
#      '2023-01-13': 4.8,
#      '2023-01-14': 4.8,
#      '2023-01-15': 4.8,
#      '2023-01-16': 4.8,
# ...
